# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Удаление-ненужных-для-обучения-моделей-колонок." data-toc-modified-id="Удаление-ненужных-для-обучения-моделей-колонок.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Удаление ненужных для обучения моделей колонок.</a></span></li><li><span><a href="#Прямое-кодирование-категориальных-признаков." data-toc-modified-id="Прямое-кодирование-категориальных-признаков.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Прямое кодирование категориальных признаков.</a></span></li><li><span><a href="#Разделение-данных-на-тренировочную,-валидационную-и-тестовую-выборки-в-пропорции-60/20/20." data-toc-modified-id="Разделение-данных-на-тренировочную,-валидационную-и-тестовую-выборки-в-пропорции-60/20/20.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Разделение данных на тренировочную, валидационную и тестовую выборки в пропорции 60/20/20.</a></span></li><li><span><a href="#Масштабирование-количественных-признаков." data-toc-modified-id="Масштабирование-количественных-признаков.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Масштабирование количественных признаков.</a></span></li><li><span><a href="#Модели-без-борьбы-с-дисбалансом" data-toc-modified-id="Модели-без-борьбы-с-дисбалансом-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Модели без борьбы с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Actual:-модель-&quot;Решающее-дерево&quot;" data-toc-modified-id="Actual:-модель-&quot;Решающее-дерево&quot;-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Actual: модель "Решающее дерево"</a></span></li><li><span><a href="#Actual:-модель-&quot;Случайный-лес&quot;" data-toc-modified-id="Actual:-модель-&quot;Случайный-лес&quot;-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Actual: модель "Случайный лес"</a></span></li><li><span><a href="#Actual:-модель-&quot;Логистическая-регрессия&quot;" data-toc-modified-id="Actual:-модель-&quot;Логистическая-регрессия&quot;-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Actual: модель "Логистическая регрессия"</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Параметр-&quot;balanced&quot;" data-toc-modified-id="Параметр-&quot;balanced&quot;-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Параметр "balanced"</a></span><ul class="toc-item"><li><span><a href="#Balanced:-модель-&quot;Решающее-дерево&quot;" data-toc-modified-id="Balanced:-модель-&quot;Решающее-дерево&quot;-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Balanced: модель "Решающее дерево"</a></span></li><li><span><a href="#Balanced:-модель-&quot;Случайный-лес&quot;" data-toc-modified-id="Balanced:-модель-&quot;Случайный-лес&quot;-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Balanced: модель "Случайный лес"</a></span></li><li><span><a href="#Balanced:-модель-&quot;Логистическая-регрессия&quot;" data-toc-modified-id="Balanced:-модель-&quot;Логистическая-регрессия&quot;-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Balanced: модель "Логистическая регрессия"</a></span></li></ul></li><li><span><a href="#Upsample" data-toc-modified-id="Upsample-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Upsample</a></span><ul class="toc-item"><li><span><a href="#Upsample:-модель-&quot;Решающее-дерево&quot;" data-toc-modified-id="Upsample:-модель-&quot;Решающее-дерево&quot;-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Upsample: модель "Решающее дерево"</a></span></li><li><span><a href="#Upsample:-модель-&quot;Случайный-лес&quot;" data-toc-modified-id="Upsample:-модель-&quot;Случайный-лес&quot;-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Upsample: модель "Случайный лес"</a></span></li><li><span><a href="#Upsample:-модель-&quot;Логистическая-регрессия&quot;" data-toc-modified-id="Upsample:-модель-&quot;Логистическая-регрессия&quot;-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Upsample: модель "Логистическая регрессия"</a></span></li></ul></li><li><span><a href="#Downsample" data-toc-modified-id="Downsample-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Downsample</a></span><ul class="toc-item"><li><span><a href="#Downsample:-модель-&quot;Решающее-дерево&quot;" data-toc-modified-id="Downsample:-модель-&quot;Решающее-дерево&quot;-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Downsample: модель "Решающее дерево"</a></span></li><li><span><a href="#Downsample:-модель-&quot;Случайный-лес&quot;" data-toc-modified-id="Downsample:-модель-&quot;Случайный-лес&quot;-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Downsample: модель "Случайный лес"</a></span></li><li><span><a href="#Downsample:-модель-&quot;Логистическая-регрессия&quot;" data-toc-modified-id="Downsample:-модель-&quot;Логистическая-регрессия&quot;-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Downsample: модель "Логистическая регрессия"</a></span></li></ul></li><li><span><a href="#Итоговая-таблица" data-toc-modified-id="Итоговая-таблица-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Итоговая таблица</a></span></li><li><span><a href="#ROC-кривая-лучшей-модели" data-toc-modified-id="ROC-кривая-лучшей-модели-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>ROC-кривая лучшей модели</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
pd.options.mode.chained_assignment = None

# %% [markdown]
# Изучим данные.

# %%
data = pd.read_csv('/datasets/Churn.csv')
display(data.sample(6))
# Out:
#       RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 7840       7841    15611756  Chapman          537   Germany  Female   47
# 8381       8382    15764314   Reilly          550   Germany    Male   36
# 6077       6078    15738588  Nebechi          660   Germany  Female   37
# 1343       1344    15645778     Reid          670     Spain    Male   42
# 6879       6880    15772618    Tyler          665    France    Male   25
# 4215       4216    15574213   Wilson          789    France  Female   53
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7840     4.0  124192.28              2          1               1
# 8381     2.0  113877.23              2          1               0
# 6077     2.0  133200.09              1          0               0
# 1343     3.0   81589.04              1          1               0
# 6879     7.0   90920.75              1          0               1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9091.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800     4.997690
# std     2886.89568  7.193619e+04     96.653299     10.487806     2.894723
# min        1.00000  1.556570e+07    350.000000     18.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     2.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# Обратим внимание на пропуски в колонке срока обслуживания.

# %%
data.isna().sum()
# Out:
# RowNumber            0
# CustomerId           0
# Surname              0
# CreditScore          0
# Geography            0
# Gender               0
# Age                  0
# Tenure             909
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %%
data['Tenure'].value_counts().sort_index().plot(kind= 'barh', title='Tenure')
plt.show()

# %% [markdown]
# Вероятно, это поле может оставаться незаполненным у новых клиентов, поэтому заполним пропуски нулями.

# %%
data['Tenure'] = data['Tenure'].fillna(0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Рассмотрим остальные колонки.

# %%
for column in ['Geography', 'Gender', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Exited']:
    data[column].value_counts().plot(kind='barh', title=column)
    plt.show()

# %% [markdown]
# - Половина клиентов из Франции, половина из Германии и Испании
# - Клиентов мужчин незначительно больше, чем женщин
# - У большинства клиентов один или два продукта
# - Кредитная карта есть у двух третей клиентов
# - Примерно поровну активных клиентов и неактивных
# - Покинула банк пятая часть клиентов

# %% [markdown]
# Построим гистограмму распределения по возрасту.

# %%
fig, ax = plt.subplots()
ax.hist(data['Age'],bins=25,rwidth = 0.8)
ax.set_title('Возраст')
ax.set_xlabel('Лет')
ax.set_ylabel('Клиентов')
plt.show()

# %% [markdown]
# Большинству клиентов от 30 до 40 лет.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Удаление ненужных для обучения моделей колонок.

# %%
data = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)
data.sample(5)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 5577          592    France  Female   62     5.0       0.00              1
# 1283          669    France    Male   45     7.0  149364.58              1
# 7811          611    France    Male   30     0.0  104145.65              1
# 6390          574     Spain  Female   37     7.0       0.00              2
# 2626          568   Germany  Female   29     2.0  129177.01              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 5577          1               1        100941.57       0
# 1283          0               1        173454.07       0
# 7811          0               0        159629.64       0
# 6390          1               0         32262.28       0
# 2626          0               1        104617.99       0

# %% [markdown]
# ### Прямое кодирование категориальных признаков.

# %%
data_ohe = pd.get_dummies(data, drop_first=True)
data_ohe.sample(5)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 449           778   47     6.0  127299.34              2          1
# 6206          802   51     7.0       0.00              1          0
# 8483          433   34     9.0  152806.74              1          1
# 4054          602   56     3.0  115895.22              3          1
# 627           752   49     2.0   78653.84              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 449                0        124694.99       0                  0
# 6206               1         40855.79       0                  0
# 8483               0         19687.99       0                  0
# 4054               0          4176.17       1                  0
# 627                0          7698.60       0                  0
#
#       Geography_Spain  Gender_Male
# 449                 1            0
# 6206                1            1
# 8483                1            1
# ...

# %% [markdown]
# ### Разделение данных на тренировочную, валидационную и тестовую выборки в пропорции 60/20/20.

# %%
target = data_ohe['Exited']
features = data_ohe.drop(['Exited'] , axis=1)
features_train, features_valid, target_train, target_valid = train_test_split(
    features, target, test_size=0.4, random_state=12345, stratify=target)
features_valid, features_test, target_valid, target_test = train_test_split(
    features_valid, target_valid, test_size=0.5, random_state=12345, stratify=target_valid)
print(features_train.shape, features_valid.shape, features_test.shape)
print(target_train.shape, target_valid.shape, target_test.shape)
# Out:
# (6000, 11) (2000, 11) (2000, 11)
# (6000,) (2000,) (2000,)

# %% [markdown]
# ### Масштабирование количественных признаков.

# %%
numeric = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
scaler = StandardScaler()
scaler.fit(features_train[numeric])
features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

# %%
features_train.sample(5)
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 8815    -0.133464  0.381372 -1.140009  0.947460       0.820981          0
# 7865     0.423086 -0.857830  1.431924 -1.219673       0.820981          0
# 2776     0.402473  0.000079  0.788940 -1.219673       0.820981          0
# 4864     0.897184  1.429928  1.431924 -1.219673      -0.914708          1
# 6754    -0.236529 -1.048476 -0.497026  1.298181      -0.914708          0
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 8815               1         0.017014                  1                0
# 7865               1        -1.554628                  0                1
# 2776               0        -1.485900                  0                0
# 4864               0        -0.294333                  0                0
# 6754               1        -1.152518                  0                1
#
#       Gender_Male
# 8815            1
# 7865            1
# ...

# %% [markdown]
# ### Модели без борьбы с дисбалансом

# %% [markdown]
# Рассмотрим три модели и посчитаем их метрики качества.

# %% [markdown]
# #### Actual: модель "Решающее дерево"

# %%
models_results = pd.DataFrame(columns=['balance', 'model','f1_score','auc_roc', 'max_depth', 'n_estimators'])

best_result = 0
best_depth = 0
for depth in range (1,10):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth)
    model.fit(features_train, target_train)
    predictions = model.predict(features_valid)
    result = f1_score(target_valid, predictions)
    if result > best_result:
        best_result = result
        best_depth = depth
        probabilities = model.predict_proba(features_valid)
        probabilities_one = probabilities[:,1]
        auc_roc = roc_auc_score(target_valid, probabilities_one)
        
models_results = models_results.append({'balance':'actual', 'model':'DecisionTreeClassifier',
                                       'f1_score':best_result,'auc_roc':auc_roc, 'max_depth':best_depth},
                                       ignore_index=True)
display(models_results.tail(1))
# Out:
#   balance                   model  f1_score   auc_roc max_depth  n_estimators
# 0  actual  DecisionTreeClassifier  0.592486  0.824706         7           NaN

# %% [markdown]
# #### Actual: модель "Случайный лес"

# %%
best_result = 0
best_depth = 0
best_estimators = 0
for estimators in range(10,300,20):
    for depth in range (1,10,2):
        model = RandomForestClassifier(random_state=12345, max_depth=depth, 
                                       n_estimators=estimators)
        model.fit(features_train, target_train)
        predictions = model.predict(features_valid)
        result = f1_score(target_valid, predictions)
        if result > best_result:
            best_result = result
            best_depth = depth
            best_estimators = estimators
            probabilities = model.predict_proba(features_valid)
            probabilities_one = probabilities[:,1]
            auc_roc = roc_auc_score(target_valid, probabilities_one)
            
models_results = models_results.append(
    {'balance':'actual', 'model':'RandomForestClassifier',
    'f1_score':best_result,'auc_roc':auc_roc, 'max_depth':best_depth, 'n_estimators':best_estimators},
    ignore_index=True)
display(models_results.tail(1))
# Out:
#   balance                   model  f1_score   auc_roc max_depth  n_estimators
# 1  actual  RandomForestClassifier  0.596923  0.873782         9          50.0

# %% [markdown]
# ####  Actual: модель "Логистическая регрессия"

# %%
model = LogisticRegression(random_state=12345, solver='liblinear')
model.fit(features_train, target_train)
predictions = model.predict(features_valid)
result = f1_score(target_valid, predictions)
probabilities = model.predict_proba(features_valid)
probabilities_one = probabilities[:,1]
auc_roc = roc_auc_score(target_valid, probabilities_one)
            
models_results = models_results.append(
    {'balance':'actual', 'model':'LogisticRegression',
    'f1_score':result,'auc_roc':auc_roc},
    ignore_index=True)
display(models_results.tail(1))
# Out:
#   balance               model  f1_score   auc_roc max_depth  n_estimators
# 2  actual  LogisticRegression  0.307692  0.787587       NaN           NaN

# %% [markdown]
# #### Вывод

# %% [markdown]
# - Модели решающего дерева и случайного леса показали приемлемые значения метрик
# - Модель логистической регрессии существенно им уступает (по метрике f1 - в два раза)
# - Имеет смысл улучшить качество моделей с помощью борьбы с дисбалансом

# %% [markdown]
# ## Борьба с дисбалансом

# %%
data_ohe['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# В данных примерно в 4 раза больше строк с целевым признаком 0. <br/>
# Рассмотрим три способа борьбы с дисбалансом и посчитаем метрики качества моделей. <br/>

# %% [markdown]
# ### Параметр "balanced"

# %% [markdown]
# #### Balanced: модель "Решающее дерево"

# %%
best_result = 0
best_depth = 0
for depth in range (1,10):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth, class_weight='balanced')
    model.fit(features_train, target_train)
    predictions = model.predict(features_valid)
    result = f1_score(target_valid, predictions)
    if result > best_result:
        best_result = result
        best_depth = depth
        probabilities = model.predict_proba(features_valid)
        probabilities_one = probabilities[:,1]
        auc_roc = roc_auc_score(target_valid, probabilities_one)
        
models_results = models_results.append({'balance':'balanced', 'model':'DecisionTreeClassifier',
                                       'f1_score':best_result,'auc_roc':auc_roc, 'max_depth':best_depth},
                                       ignore_index=True)
display(models_results.tail(1))
# Out:
#     balance                   model  f1_score   auc_roc max_depth  \
# 3  balanced  DecisionTreeClassifier  0.575926  0.823412         6
#
#    n_estimators
# 3           NaN

# %% [markdown]
# #### Balanced: модель "Случайный лес"

# %%
best_result = 0
best_depth = 0
best_estimators = 0
for estimators in range(10,300,25):
    for depth in range (1,10,2):
        model = RandomForestClassifier(random_state=12345, max_depth=depth, 
                                       n_estimators=estimators, class_weight='balanced')
        model.fit(features_train, target_train)
        predictions = model.predict(features_valid)
        result = f1_score(target_valid, predictions)
        if result > best_result:
            best_result = result
            best_depth = depth
            best_estimators = estimators
            probabilities = model.predict_proba(features_valid)
            probabilities_one = probabilities[:,1]
            auc_roc = roc_auc_score(target_valid, probabilities_one)
            
models_results = models_results.append(
    {'balance':'balanced', 'model':'RandomForestClassifier',
    'f1_score':best_result,'auc_roc':auc_roc, 'max_depth':best_depth, 'n_estimators':best_estimators},
    ignore_index=True)
display(models_results.tail(1))
# Out:
#     balance                   model  f1_score   auc_roc max_depth  \
# 4  balanced  RandomForestClassifier  0.648961  0.870495         9
#
#    n_estimators
# 4         160.0

# %% [markdown]
# ####  Balanced: модель "Логистическая регрессия"

# %%
model = LogisticRegression(random_state=12345, solver='liblinear', class_weight='balanced')
model.fit(features_train, target_train)
predictions = model.predict(features_valid)
result = f1_score(target_valid, predictions)
probabilities = model.predict_proba(features_valid)
probabilities_one = probabilities[:,1]
auc_roc = roc_auc_score(target_valid, probabilities_one)

models_results = models_results.append(
    {'balance':'balanced', 'model':'LogisticRegression',
    'f1_score':result,'auc_roc':auc_roc},
    ignore_index=True)
display(models_results.tail(1))
# Out:
#     balance               model  f1_score   auc_roc max_depth  n_estimators
# 5  balanced  LogisticRegression   0.53029  0.793776       NaN           NaN

# %% [markdown]
# ### Upsample

# %%
def upsample(features, target, repeat):
    features_zero = features[target==0]
    features_one = features[target==1]
    target_zero = target[target==0]
    target_one = target[target==1]
    features_upsampled = pd.concat([features_zero] + [features_one]*repeat)
    target_upsampled = pd.concat([target_zero] + [target_one]*repeat)
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    return features_upsampled, target_upsampled

features_upsampled, target_upsampled = upsample(features_train, target_train, 4)
print(features_upsampled.shape)
print(target_upsampled.shape)
print(target_upsampled.value_counts())
# Out:
# (9666, 11)
# (9666,)
# 1    4888
# 0    4778
# Name: Exited, dtype: int64

# %% [markdown]
# #### Upsample: модель "Решающее дерево"

# %%
best_result = 0
best_depth = 0
for depth in range (1,10):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth)
    model.fit(features_upsampled, target_upsampled)
    predictions = model.predict(features_valid)
    result = f1_score(target_valid, predictions)
    if result > best_result:
        best_result = result
        best_depth = depth
        probabilities = model.predict_proba(features_valid)
        probabilities_one = probabilities[:,1]
        auc_roc = roc_auc_score(target_valid, probabilities_one)
        
models_results = models_results.append({'balance':'upsample', 'model':'DecisionTreeClassifier',
                                       'f1_score':best_result,'auc_roc':auc_roc, 'max_depth':best_depth},
                                       ignore_index=True)
display(models_results.tail(1))
# Out:
#     balance                   model  f1_score   auc_roc max_depth  \
# 6  upsample  DecisionTreeClassifier  0.575926  0.823428         6
#
#    n_estimators
# 6           NaN

# %% [markdown]
# #### Upsample: модель "Случайный лес"

# %%
best_result = 0
best_depth = 0
best_estimators = 0
for estimators in range(10,300,25):
    for depth in range (1,10,2):
        model = RandomForestClassifier(
            random_state=12345, max_depth=depth, n_estimators=estimators)
        model.fit(features_upsampled, target_upsampled)
        predictions = model.predict(features_valid)
        result = f1_score(target_valid, predictions)
        if result > best_result:
            best_result = result
            best_depth = depth
            best_estimators = estimators
            probabilities = model.predict_proba(features_valid)
            probabilities_one = probabilities[:,1]
            auc_roc = roc_auc_score(target_valid, probabilities_one)
            
models_results = models_results.append(
    {'balance':'upsample', 'model':'RandomForestClassifier',
    'f1_score':best_result,'auc_roc':auc_roc, 'max_depth':best_depth, 'n_estimators':best_estimators},
    ignore_index=True)
display(models_results.tail(1))
# Out:
#     balance                   model  f1_score   auc_roc max_depth  \
# 7  upsample  RandomForestClassifier  0.645856  0.873479         9
#
#    n_estimators
# 7         210.0

# %% [markdown]
# ####  Upsample: модель "Логистическая регрессия"

# %%
model = LogisticRegression(random_state=12345, solver='liblinear')
model.fit(features_upsampled, target_upsampled)
predictions = model.predict(features_valid)
result = f1_score(target_valid, predictions)
probabilities = model.predict_proba(features_valid)
probabilities_one = probabilities[:,1]
auc_roc = roc_auc_score(target_valid, probabilities_one)

models_results = models_results.append(
    {'balance':'upsample', 'model':'LogisticRegression',
    'f1_score':result,'auc_roc':auc_roc},
    ignore_index=True)
display(models_results.tail(1))
# Out:
#     balance               model  f1_score   auc_roc max_depth  n_estimators
# 8  upsample  LogisticRegression  0.524675  0.793822       NaN           NaN

# %% [markdown]
# ### Downsample

# %%
def downsample(features, target, fraction):
    features_zero = features[target==0]
    features_one = features[target==1]
    target_zero = target[target==0]
    target_one = target[target==1]
    features_downsampled = pd.concat(
        [features_zero.sample(frac=fraction, random_state=12345)] + [features_one])
    target_downsampled = pd.concat(
        [target_zero.sample(frac=fraction, random_state=12345)] + [target_one])
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)
    return features_downsampled, target_downsampled

features_downsampled, target_downsampled = downsample(features_train, target_train, 0.25)
print(features_downsampled.shape)
print(target_downsampled.shape)
print(target_downsampled.value_counts())
# Out:
# (2416, 11)
# (2416,)
# 1    1222
# 0    1194
# Name: Exited, dtype: int64

# %% [markdown]
# #### Downsample: модель "Решающее дерево"

# %%
best_result = 0
best_depth = 0
for depth in range (1,10):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth)
    model.fit(features_downsampled, target_downsampled)
    predictions = model.predict(features_valid)
    result = f1_score(target_valid, predictions)
    if result > best_result:
        best_result = result
        best_depth = depth
        probabilities = model.predict_proba(features_valid)
        probabilities_one = probabilities[:,1]
        auc_roc = roc_auc_score(target_valid, probabilities_one)
        
models_results = models_results.append({'balance':'downsample', 'model':'DecisionTreeClassifier',
                                       'f1_score':best_result,'auc_roc':auc_roc, 'max_depth':best_depth},
                                       ignore_index=True)
display(models_results.tail(1))
# Out:
#       balance                   model  f1_score   auc_roc max_depth  \
# 9  downsample  DecisionTreeClassifier  0.593928  0.847232         6
#
#    n_estimators
# 9           NaN

# %% [markdown]
# #### Downsample: модель "Случайный лес"

# %%
best_result = 0
best_depth = 0
best_estimators = 0
for estimators in range(10,300,25):
    for depth in range (1,10,2):
        model = RandomForestClassifier(
            random_state=12345, max_depth=depth, n_estimators=estimators)
        model.fit(features_downsampled, target_downsampled)
        predictions = model.predict(features_valid)
        result = f1_score(target_valid, predictions)
        if result > best_result:
            best_result = result
            best_depth = depth
            best_estimators = estimators
            probabilities = model.predict_proba(features_valid)
            probabilities_one = probabilities[:,1]
            auc_roc = roc_auc_score(target_valid, probabilities_one)
            
models_results = models_results.append(
    {'balance':'downsample', 'model':'RandomForestClassifier',
    'f1_score':best_result,'auc_roc':auc_roc, 'max_depth':best_depth, 'n_estimators':best_estimators},
    ignore_index=True)
display(models_results.tail(1))
# Out:
#        balance                   model  f1_score   auc_roc max_depth  \
# 10  downsample  RandomForestClassifier  0.629876  0.869778         7
#
#     n_estimators
# 10         160.0

# %% [markdown]
# ####  Downsample: модель "Логистическая регрессия"

# %%
model = LogisticRegression(random_state=12345, solver='liblinear')
model.fit(features_downsampled, target_downsampled)
predictions = model.predict(features_valid)
result = f1_score(target_valid, predictions)
probabilities = model.predict_proba(features_valid)
probabilities_one = probabilities[:,1]
auc_roc = roc_auc_score(target_valid, probabilities_one)

models_results = models_results.append(
    {'balance':'downsample', 'model':'LogisticRegression',
    'f1_score':result,'auc_roc':auc_roc},
    ignore_index=True)
display(models_results.tail(1))
# Out:
#        balance               model  f1_score   auc_roc max_depth  n_estimators
# 11  downsample  LogisticRegression  0.525043  0.792741       NaN           NaN

# %% [markdown]
# ### Итоговая таблица

# %%
display(models_results.sort_values('f1_score', ascending=False))
# Out:
#        balance                   model  f1_score   auc_roc max_depth  \
# 4     balanced  RandomForestClassifier  0.648961  0.870495         9
# 7     upsample  RandomForestClassifier  0.645856  0.873479         9
# 10  downsample  RandomForestClassifier  0.629876  0.869778         7
# 1       actual  RandomForestClassifier  0.596923  0.873782         9
# 9   downsample  DecisionTreeClassifier  0.593928  0.847232         6
# 0       actual  DecisionTreeClassifier  0.592486  0.824706         7
# 3     balanced  DecisionTreeClassifier  0.575926  0.823412         6
# 6     upsample  DecisionTreeClassifier  0.575926  0.823428         6
# 5     balanced      LogisticRegression  0.530290  0.793776       NaN
# 11  downsample      LogisticRegression  0.525043  0.792741       NaN
# 8     upsample      LogisticRegression  0.524675  0.793822       NaN
# 2       actual      LogisticRegression  0.307692  0.787587       NaN
#
#     n_estimators
# 4          160.0
# 7          210.0
# ...

# %% [markdown]
# Лучшая модель - модель случайного леса с параметром 'balanced' с количеством деревьев 160 и максимальной глубиной 9.

# %% [markdown]
# ### ROC-кривая лучшей модели

# %%
model =  RandomForestClassifier(random_state=12345, n_estimators=160, max_depth = 9, class_weight='balanced')
model.fit(features_train, target_train)
probabilities = model.predict_proba(features_valid)
probabilities_one = probabilities[:, 1]
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one)
plt.figure(figsize=[12,9])
plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')
plt.plot(fpr, tpr, label='RandomForestClassifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend(loc='lower right', fontsize='large')
plt.show()
auc_roc = roc_auc_score(target_valid, probabilities_one)
print('AUC-ROC:', auc_roc)
# Out:
# AUC-ROC: 0.8704952458370282

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Объединим тренировочную и валидационную выборки. Обучим на них лучшую модель и проверим на тестовой выборке.

# %%
features_full_train = pd.concat([features_train, features_valid])
target_full_train = pd.concat([target_train, target_valid])
model =  RandomForestClassifier(random_state=12345, n_estimators=160, max_depth = 9, class_weight='balanced')
model.fit(features_full_train, target_full_train)
predictions = model.predict(features_test)
result = f1_score(target_test, predictions)
probabilities = model.predict_proba(features_test)
probabilities_one = probabilities[:,1]
auc_roc = roc_auc_score(target_test, probabilities_one)
print('f1-score:', result)
print('AUC-ROC:', auc_roc)
# Out:
# f1-score: 0.6152099886492622
# AUC-ROC: 0.8586429264395364

# %% [markdown]
# ## Вывод

# %% [markdown]
#  - Задача прогнозирования оттока клиентов выполнена
#  - Протестированы несколько алгоритмов создания и обучения моделей
#  - Проведены масштабирование значений и балансировка классов для улучшения метрик
#  - Лучшая модель показала на тестовой выборке удовлетворительные результаты:
#      - Значение метрики f1 выше 0.59
#      - AUC-ROC значительно лучше, чем у случайной модели

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*
